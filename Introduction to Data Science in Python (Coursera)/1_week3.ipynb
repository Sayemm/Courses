# %%
import pandas as pd
import numpy  as np

df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris         Sponge  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Filip          Spoon   5.0

# %%
df['Delevered'] = True
df
# Out:
#           Name Item Purchased  Cost        Date  Delevered
# Store 1  Chris         Sponge  22.5  December 1       True
# Store 1  Kevyn   Kitty Litter   2.5   January 1       True
# Store 2  Filip          Spoon   5.0     mid-May       True

# %%
df['Date'] = ['December 1', 'January 1', 'mid-May']
df
# Out:
#           Name Item Purchased  Cost        Date
# Store 1  Chris         Sponge  22.5  December 1
# Store 1  Kevyn   Kitty Litter   2.5   January 1
# Store 2  Filip          Spoon   5.0     mid-May

# %%
ndf = df.reset_index()

ndf['Date'] = pd.Series({0: 'm1', 2:'m3'})

ndf
# Out:
#      index   Name Item Purchased  Cost Date  Delevered  Feedback
# 0  Store 1  Chris         Sponge  22.5   m1       True  Positive
# 1  Store 1  Kevyn   Kitty Litter   2.5  NaN       True      None
# 2  Store 2  Filip          Spoon   5.0   m3       True  Negative

# %%
df['Feedback'] = ['Positive', None, 'Negative']
df
# Out:
#           Name Item Purchased  Cost        Date  Feedback
# Store 1  Chris         Sponge  22.5  December 1  Positive
# Store 1  Kevyn   Kitty Litter   2.5   January 1      None
# Store 2  Filip          Spoon   5.0     mid-May  Negative

# %%
#Join using index as common part

pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')
print(staff_df.head())
print()
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
df = pd.read_csv('cars.csv')

df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
#Join using column name as common part

staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business

# %%
df = pd.read_csv('census.csv')

df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])
print(staff_df, '\n')
print(student_df, '\n')
print(staff_df.loc[2]['Role'])
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])

# # products and invoices were already initilized.

# answer = pd.merge(products, invoices, left_index=True, right_on='Product ID')

# answer
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader
#
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering
#
# Grader
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %%
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County             54571                54571
# ...

# %%
#Method Chaining

# (df.where(df['SUMLEV']==50)
#     .dropna()
#     .set_index(['STNAME','CTYNAME'])
#     .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))

# Can you use method chaining to modify the DataFrame df in one statement to drop any entries where 'Quantity' is 0 and rename the column 'Weight' to 'Weight (oz.)'?
# print(df.drop(df[df['Quantity'] == 0].index)
#   .rename(columns={'Weight': 'Weight (oz.)'}))

# %%
df = pd.read_csv('census.csv')

# Take a row and based of 6 popultaion comulm return a new min and max row
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min' : np.min(data), 'max' : np.max(data)})

df.apply(min_max, axis=1)
# Out:
#           min      max
# 0     4785161  4858979
# 1       54660    55347
# 2      183193   203709
# 3       26489    27341
# 4       22512    22861
# ...       ...      ...
# 3188    43593    45162
# 3189    21297    23125
# 3190    20822    21102
# 3191     8316     8545
# 3192     7065     7234
#
# [3193 rows x 2 columns]

# %%
print(df.drop(df[df['REGION']==3].index).rename(columns={'REGION' : 'Region'}))
# Out:
#       SUMLEV  Region  DIVISION  STATE  COUNTY   STNAME  \
# 68        40       4         9      2       0   Alaska
# 69        50       4         9      2      13   Alaska
# 70        50       4         9      2      16   Alaska
# 71        50       4         9      2      20   Alaska
# 72        50       4         9      2      50   Alaska
# ...      ...     ...       ...    ...     ...      ...
# 3188      50       4         8     56      37  Wyoming
# 3189      50       4         8     56      39  Wyoming
# 3190      50       4         8     56      41  Wyoming
# 3191      50       4         8     56      43  Wyoming
# 3192      50       4         8     56      45  Wyoming
#
#                          CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 68                        Alaska         710231             710249
# 69        Aleutians East Borough           3141               3141
# 70    Aleutians West Census Area           5561               5561
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    
    return row

df.apply(min_max, axis=1)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
rows = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']

df.apply(lambda x: np.max(x[rows]), axis=1)
# Out:
# 0       4858979
# 1         55347
# 2        203709
# 3         27341
# 4         22861
#          ...
# 3188      45162
# 3189      23125
# 3190      21102
# 3191       8545
# 3192       7234
# Length: 3193, dtype: int64

# %%
df = pd.read_csv('census.csv')

df = df[df['SUMLEV']==50]

# %%
# %%timeit -n 10

for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Countries in state ' + state + ' have an average of ' + str(avg))
# Out:
# Countries in state Alabama have an average of 71339.34328358209
# Countries in state Alaska have an average of 24490.724137931036
# Countries in state Arizona have an average of 426134.4666666667
# Countries in state Arkansas have an average of 38878.90666666667
# Countries in state California have an average of 642309.5862068966
# Countries in state Colorado have an average of 78581.1875
# Countries in state Connecticut have an average of 446762.125
# Countries in state Delaware have an average of 299311.3333333333
# Countries in state District of Columbia have an average of 601723.0
# Countries in state Florida have an average of 280616.5671641791
# Countries in state Georgia have an average of 60928.63522012578
# Countries in state Hawaii have an average of 272060.2
# Countries in state Idaho have an average of 35626.86363636364
# Countries in state Illinois have an average of 125790.50980392157
# Countries in state Indiana have an average of 70476.10869565218
# ...

# %%
# %%timeit -n 10

for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Countries in state ' + group + ' have an average of ' + str(avg))
# Out:
# Countries in state Alabama have an average of 71339.34328358209
# Countries in state Alaska have an average of 24490.724137931036
# Countries in state Arizona have an average of 426134.4666666667
# Countries in state Arkansas have an average of 38878.90666666667
# Countries in state California have an average of 642309.5862068966
# Countries in state Colorado have an average of 78581.1875
# Countries in state Connecticut have an average of 446762.125
# Countries in state Delaware have an average of 299311.3333333333
# Countries in state District of Columbia have an average of 601723.0
# Countries in state Florida have an average of 280616.5671641791
# Countries in state Georgia have an average of 60928.63522012578
# Countries in state Hawaii have an average of 272060.2
# Countries in state Idaho have an average of 35626.86363636364
# Countries in state Illinois have an average of 125790.50980392157
# Countries in state Indiana have an average of 70476.10869565218
# ...

# %%
df = pd.read_csv('census.csv')
df = df.set_index('STNAME') #group by index according to the function

def fun(item):
    if item[0] < 'M':
        return 0
    if item[0] < 'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1196 records in group 0 for processing.
# There are 1154 records in group 1 for processing.
# There are 843 records in group 2 for processing.

# %%
df.groupby('STNAME').agg({'CENSUS2010POP' : np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
# print(df.groupby('STNAME').apply(lambda df,a,b: sum(df[a] * df[b]), 'REGION', 'DIVISION'))


# Or alternatively without using a lambda:
def totalweight(df, w, q):
       return sum(df[w] * df[q])
       
print(df.groupby('STNAME').apply(totalweight, 'REGION', 'DIVISION'))
# Out:
# STNAME
# Alabama                 1224
# Alaska                  1080
# Arizona                  512
# Arkansas                1596
# California              2124
# Colorado                2080
# Connecticut                9
# Delaware                  60
# District of Columbia      30
# Florida                 1020
# Georgia                 2400
# Hawaii                   216
# Idaho                   1440
# Illinois                 618
# Indiana                  558
# Iowa                     800
# Kansas                   848
# Kentucky                2178
# Louisiana               1365
# Maine                     17
# Maryland                 375
# Massachusetts             15
# Michigan                 504
# Minnesota                704
# Mississippi             1494
# Missouri                 928
# Montana                 1824
# Nebraska                 752
# Nevada                   576
# New Hampshire             11
# New Jersey                44
# ...

# %%
df = pd.read_csv('census.csv')

(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010'].agg({'Avg': np.average, 'Sum': np.sum}))

# level = 0 means groupby by index
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                Avg       Sum
# STNAME
# Alabama               1.407400e+05   9570322
# Alaska                4.760140e+04   1428042
# Arizona               8.010260e+05  12816416
# Arkansas              7.690511e+04   5844788
# California            1.265562e+06  74668158
# Colorado              1.553309e+05  10096508
# Connecticut           7.954927e+05   7159434
# Delaware              4.498955e+05   1799582
# District of Columbia  6.051260e+05   1210252
# Florida               5.544085e+05  37699780
# Georgia               1.214182e+05  19426908
# Hawaii                4.546600e+05   2727960
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011'].agg({'Avg': np.average, 'Sum': np.sum}))
# Out:
#                                  Avg                             Sum  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 1.407400e+05    1.412091e+05         9570322
# Alaska                  4.760140e+04    4.818133e+04         1428042
# Arizona                 8.010260e+05    8.085915e+05        12816416
# Arkansas                7.690511e+04    7.732995e+04         5844788
# California              1.265562e+06    1.277967e+06        74668158
# Colorado                1.553309e+05    1.575225e+05        10096508
# Connecticut             7.954927e+05    7.977242e+05         7159434
# Delaware                4.498955e+05    4.539580e+05         1799582
# District of Columbia    6.051260e+05    6.204720e+05         1210252
# Florida                 5.544085e+05    5.619274e+05        37699780
# Georgia                 1.214182e+05    1.226535e+05        19426908
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))

# Label of dictionary is same as groupby
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  1.407400e+05          9602216
# Alaska                   4.760140e+04          1445440
# Arizona                  8.010260e+05         12937464
# Arkansas                 7.690511e+04          5877076
# California               1.265562e+06         75400068
# Colorado                 1.553309e+05         10238960
# Connecticut              7.954927e+05          7179518
# Delaware                 4.498955e+05          1815832
# District of Columbia     6.051260e+05          1240944
# Florida                  5.544085e+05         38211066
# Georgia                  1.214182e+05         19624560
# Hawaii                   4.546600e+05          2756454
# Idaho                    6.982160e+04          3168268
# Illinois                 2.493446e+05         25723764
# Indiana                  1.395826e+05         13033690
# Iowa                     6.101388e+04          6130778
# ...

# %%
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
from pandas.api.types import CategoricalDtype

grades = df['Grades'].astype(CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], ordered=True))

grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
# grades > 'C'


# Casting this series in low , medium & high
# s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low'])
# s.astype(CategoricalDtype(categories=['Low', 'Medium', 'High'], ordered=True))
# Out:
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: category
# Categories (3, object): [Low < Medium < High]

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
pd.cut(df['avg'],10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# ...

# %%
s = pd.Series([168, 180, 174, 190, 170, 185, 179, 181, 175, 169, 182, 177, 180, 171])


pd.cut(s, 3)

# You can also add labels for the sizes [Small < Medium < Large].
# pd.cut(s, 3, labels=['Small', 'Medium', 'Large'])
# Out:
# 0     (167.978, 175.333]
# 1     (175.333, 182.667]
# 2     (167.978, 175.333]
# 3       (182.667, 190.0]
# 4     (167.978, 175.333]
# 5       (182.667, 190.0]
# 6     (175.333, 182.667]
# 7     (175.333, 182.667]
# 8     (167.978, 175.333]
# 9     (167.978, 175.333]
# 10    (175.333, 182.667]
# 11    (175.333, 182.667]
# 12    (175.333, 182.667]
# 13    (167.978, 175.333]
# dtype: category
# Categories (3, interval[float64]): [(167.978, 175.333] < (175.333, 182.667] < (182.667, 190.0]]

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc = np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %%
pd.pivot_table(df, values=['(kW)', '(km)'], index=['YEAR', 'Make'])
# Out:
#                        (kW)        (km)
# YEAR Make
# 2012 MITSUBISHI   49.000000  100.000000
#      NISSAN       80.000000  117.000000
# 2013 FORD        107.000000  122.000000
#      MITSUBISHI   49.000000  100.000000
#      NISSAN       80.000000  117.000000
#      SMART        35.000000  109.000000
#      TESLA       280.000000  352.750000
# 2014 CHEVROLET   104.000000  131.000000
#      FORD        107.000000  122.000000
#      MITSUBISHI   49.000000  100.000000
#      NISSAN       80.000000  135.000000
#      SMART        35.000000  109.000000
#      TESLA       268.333333  395.666667
# 2015 BMW         125.000000  130.000000
#      CHEVROLET   104.000000  131.000000
#      FORD        107.000000  122.000000
#      KIA          81.000000  149.000000
#      MITSUBISHI   49.000000  100.000000
#      NISSAN       80.000000  135.000000
#      SMART        35.000000  109.000000
#      TESLA       320.666667  394.333333
# 2016 BMW         125.000000  130.000000
# ...

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc = [np.mean, np.min], margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# ...

# %%
# Time series and date functionality
### Timestamp

pd.Timestamp('9/1/2016 10:05AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %%
###Period

pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %%
###DatetimeIndex

t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
print(t1)
print(type(t1.index))
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
###Periodindex

t2 = pd.Series(list('def'),[pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])
print(t2)
print(type(t2.index))
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object
# <class 'pandas.core.indexes.period.PeriodIndex'>

# %%
###Converting to Datetime

d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
t3 = pd.DataFrame(np.random.randint(10, 100, (4, 2)), index = d1, columns=list('ab'))
print(t3)

t3.index = pd.to_datetime(t3.index)

print(t3)
# Out:
#                a   b
# 2 June 2013   71  51
# Aug 29, 2014  64  35
# 2015-06-26    58  70
# 7/12/16       72  96
#              a   b
# 2013-06-02  71  51
# 2014-08-29  64  35
# 2015-06-26  58  70
# 2016-07-12  72  96

# %%
pd.to_datetime('25.2.12', dayfirst=True)
# Out:
# Timestamp('2012-02-25 00:00:00')

# %%
###Timedeltas
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/3/2016 8:10AM')-pd.Timestamp('9/1/2016 8:25PM')
# Out:
# Timedelta('1 days 11:45:00')

# %%
pd.Timestamp('9/3/2016 8:10AM') + pd.Timedelta('12D 4H')
# Out:
# Timestamp('2016-09-15 12:10:00')

# %%
###Working with dates in dataframe

dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')

print(dates)
print(type(dates))

df = pd.DataFrame({'Count 1': 100+np.random.randint(-5, 10, 9).cumsum(),
                   'Count 2': 120+np.random.randint(-5, 10, 9)}, index=dates)

df
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#             Count 1  Count 2
# 2016-10-02      101      121
# 2016-10-16      102      118
# 2016-10-30      108      115
# 2016-11-13      105      129
# 2016-11-27      101      120
# 2016-12-11       98      119
# 2016-12-25       93      116
# 2017-01-08       91      128
# 2017-01-22       95      122

# %%
print(df.index.weekday_name, '\n')
print(df.diff(), '\n')
print(df.resample('M').mean(), '\n')
print(df['2017'], '\n')
print(df['2016-12'], '\n')
print(df['2016-12':], '\n') #from this date to onward

df.asfreq('W', method='ffill')
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday'],
#       dtype='object')
#
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16      1.0     -3.0
# 2016-10-30      6.0     -3.0
# 2016-11-13     -3.0     14.0
# 2016-11-27     -4.0     -9.0
# 2016-12-11     -3.0     -1.0
# 2016-12-25     -5.0     -3.0
# 2017-01-08     -2.0     12.0
# 2017-01-22      4.0     -6.0
#
#                Count 1  Count 2
# 2016-10-31  103.666667    118.0
# 2016-11-30  103.000000    124.5
# 2016-12-31   95.500000    117.5
# 2017-01-31   93.000000    125.0
#
#             Count 1  Count 2
# 2017-01-08       91      128
# 2017-01-22       95      122
#
#             Count 1  Count 2
# 2016-12-11       98      119
# 2016-12-25       93      116
#
#             Count 1  Count 2
# 2016-12-11       98      119
# 2016-12-25       93      116
# 2017-01-08       91      128
# 2017-01-22       95      122
#             Count 1  Count 2
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

df.plot()
