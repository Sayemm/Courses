# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

plt.style.use('seaborn-colorblind')

# %%
df = pd.read_csv("bangladesh.csv")
of = pd.read_csv("other_country.csv")

print(df.head())
print(of.head())
# Out:
#     Opposition  Win Percentage
# 0  Afghanistan           62.50
# 1    Australia            5.00
# 2      Bermuda          100.00
# 3       Canada           50.00
# 4      England           19.04
#     Opposition   India  Pakistan  Srilanka
# 0  Afghanistan   83.33    100.00      75.0
# 1    Australia   40.00     32.17      34.4
# 2      Bermuda  100.00    100.00     100.0
# 3       Canada  100.00    100.00     100.0
# 4      England   55.67     37.64      50.0

# %%
plt.figure(figsize = (10, 5))

plt.plot(df.Opposition, df['Win Percentage'], label = 'Bangladesh')
plt.plot(of.Opposition, of.India, label = 'India')
plt.plot(of.Opposition, of.Pakistan, label = 'Pakistan')
plt.plot(of.Opposition, of.Srilanka, label = 'Srilanka')

plt.xlim(0, 14)

plt.xlabel('Country')
plt.ylabel('Win Percentage')
plt.title('Win% comparison in Cricket with Bangladesh and other country')

plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.legend()
plt.savefig('assignment4.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
